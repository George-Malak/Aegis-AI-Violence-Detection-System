# %%
! git clone https://github.com/George-Malak/Aegis-AI-Violence-Detection-System.git
# Out:
# Cloning into 'Aegis-AI-Violence-Detection-System'...
# remote: Enumerating objects: 258, done.
# remote: Counting objects: 100% (258/258), done.
# remote: Compressing objects: 100% (206/206), done.
# remote: Total 258 (delta 71), reused 189 (delta 36), pack-reused 0 (from 0)
# Receiving objects: 100% (258/258), 5.74 MiB | 9.73 MiB/s, done.
# Resolving deltas: 100% (71/71), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_1885/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
from pathlib import Path
import sys

ROOT_DIR = Path.cwd().resolve()
while not (ROOT_DIR / "ml_core").exists() and ROOT_DIR != ROOT_DIR.parent:
    ROOT_DIR = ROOT_DIR.parent

if str(ROOT_DIR) not in sys.path:
    sys.path.insert(0, str(ROOT_DIR))

from ml_core.src.preprocessing.video_preprocessor import VideoPreprocessor
from ml_core.src.visualization.video_visualizer import VideoVisualizer

# %%
processor = VideoPreprocessor(target_frames=16, target_size=(224, 224))
visualizer = VideoVisualizer()
sample_path = ROOT_DIR / "data" / "sample_videos" / "sample.mp4"

if sample_path.exists():
    processed_data = processor.preprocess_video(str(sample_path))
    if processed_data is not None:
        print(f"Tensor shape: {processed_data.shape}")
else:
    processed_data = None
    print(f"Sample video not found at: {sample_path}")
# Out:
# Sample video not found at: C:\Users\georg\OneDrive\Desktop\DEPI\Project\Aegis-AI-Violence-Detection-System\data\sample_videos\sample.mp4

# %%
if processed_data is not None:
    visualizer.plot_pixel_distribution(processed_data)

# %%
if processed_data is not None:
    visualizer.plot_motion_energy(processed_data)

# %%
# Uncomment to play the processed video with motion tracking.
if processed_data is not None:
    processor.play_processed_video_with_motion_tracking(processed_data, fps=4)
