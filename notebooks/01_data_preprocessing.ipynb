# %%
! git clone https://github.com/George-Malak/Aegis-AI-Violence-Detection-System.git
# Out:
# Cloning into 'Aegis-AI-Violence-Detection-System'...
# remote: Enumerating objects: 319, done.
# remote: Counting objects: 100% (319/319), done.
# remote: Compressing objects: 100% (244/244), done.
# remote: Total 319 (delta 101), reused 224 (delta 53), pack-reused 0 (from 0)
# Receiving objects: 100% (319/319), 5.74 MiB | 15.24 MiB/s, done.
# Resolving deltas: 100% (101/101), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os
from pathlib import Path

SRC_PATH = Path('/content/Aegis-AI-Violence-Detection-System/ml_core/src').resolve()
if str(SRC_PATH) not in sys.path:
    sys.path.insert(0, str(SRC_PATH))

from preprocessing.video_preprocessor import VideoPreprocessor
from visualization.video_visualizer import VideoVisualizer
# Out:
# /content/Aegis-AI-Violence-Detection-System/ml_core/src/preprocessing/video_preprocessor.py:232: SyntaxWarning: invalid escape sequence '\d'
#   sample_path = r"D:\downloads\Movies\Robbery150_x264.mp4"

# %%
ROOT_DIR = Path('/content/drive/MyDrive/DEPI Project').resolve()

VIDEO_PATH = ROOT_DIR / "Train" / "Shooting"
print(f"Executing preprocessing pipeline test on: {VIDEO_PATH}")

cont = os.listdir(VIDEO_PATH)
print(len(cont))
print(cont[5])
VIDEO_PATH = VIDEO_PATH / cont[5]
print(VIDEO_PATH)
# Out:
# Executing preprocessing pipeline test on: /content/drive/.shortcut-targets-by-id/1dY6DTYepRVAzSHcM_vTLO7qysH-tzoji/DEPI Project/Train/Shooting
# 209
# Shooting009_x264.mp4
# /content/drive/.shortcut-targets-by-id/1dY6DTYepRVAzSHcM_vTLO7qysH-tzoji/DEPI Project/Train/Shooting/Shooting009_x264.mp4

# %%
preprocessor = VideoPreprocessor(target_frames=16, target_size=(224, 224))
output_tensor = preprocessor.preprocess(VIDEO_PATH)

# %%
if output_tensor is not None:
    print("\n" + "="*40)
    print(" PIPELINE EXPERIMENT RESULTS")
    print("="*40)
    print(f"Output Shape (Frames, Height, Width, Channels): {output_tensor.shape}")
    print(f"Data Representation Format Type                : {output_tensor.dtype}")
    print(f"Value Bounds - Minimum Value Obtained         : {output_tensor.min()}")
    print(f"Value Bounds - Maximum Value Obtained         : {output_tensor.max()}")
    print("="*40)
    print("Status: Validation complete. Array format is model training ready.")
else:
    print("Execution Error: Failed to produce normalized matrix output sequence.")
# Out:
# ...
#  PIPELINE EXPERIMENT RESULTS
# ...
# Output Shape (Frames, Height, Width, Channels): (16, 224, 224, 3)
# Data Representation Format Type                : float32
# Value Bounds - Minimum Value Obtained         : 0.007843137718737125
# Value Bounds - Maximum Value Obtained         : 1.0
# ...
# Status: Validation complete. Array format is model training ready.
